# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.11.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("aps_data.csv")

# %%
dataset
# Out:
#           class    aa_000    ab_000    ac_000    ad_000    ae_000    af_000  \
# 0     -0.992188  0.117188 -0.289062  0.992188 -0.007812 -0.046875 -0.054688
# 1     -0.992188 -0.179688 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
# 2     -0.992188 -0.125000 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
# 3     -0.992188 -0.406250 -0.289062 -0.468750 -0.007812 -0.046875 -0.007812
# 4     -0.992188  0.007812 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
# ...         ...       ...       ...       ...       ...       ...       ...
# 59995 -0.992188  0.640625  0.007812 -0.468750 -0.007812 -0.046875 -0.054688
# 59996 -0.992188 -0.390625 -0.289062  0.992188 -0.007812 -0.046875 -0.054688
# 59997 -0.992188 -0.406250 -0.289062  0.992188 -0.007812 -0.046875 -0.054688
# 59998 -0.992188  0.140625  0.304688  0.992188 -0.007812 -0.046875 -0.054688
# 59999 -0.992188 -0.132812  0.281250 -0.468750 -0.007812 -0.046875 -0.054688
#
#          ag_000   ag_001    ag_002  ...    ee_002    ee_003    ee_004  \
# 0     -0.007812 -0.03125 -0.054688  ...  0.687500  0.515625  0.234375
# 1     -0.007812 -0.03125 -0.054688  ... -0.023438 -0.062500 -0.132812
# 2     -0.007812 -0.03125 -0.054688  ... -0.140625 -0.093750 -0.015625
# 3     -0.007812 -0.03125 -0.054688  ... -0.382812 -0.382812 -0.375000
# 4     -0.007812 -0.03125 -0.054688  ...  0.156250  0.031250 -0.031250
# ...         ...      ...       ...  ...       ...       ...       ...
# 59995 -0.007812 -0.03125 -0.054688  ...  0.476562  0.656250  0.718750
# 59996 -0.007812 -0.03125 -0.054688  ... -0.375000 -0.375000 -0.359375
# 59997 -0.007812 -0.03125 -0.054688  ... -0.382812 -0.382812 -0.375000
# 59998 -0.007812 -0.03125 -0.054688  ...  0.218750  0.023438 -0.085938
# 59999 -0.007812 -0.03125 -0.054688  ... -0.007812 -0.046875 -0.085938
#
#          ee_005    ee_006    ee_007    ee_008    ee_009    ef_000    eg_000
# 0      0.070312  0.007812 -0.109375 -0.140625 -0.171875 -0.023438 -0.023438
# 1     -0.132812 -0.187500 -0.148438 -0.085938 -0.140625 -0.023438 -0.023438
# 2      0.015625 -0.007812 -0.109375 -0.093750 -0.164062 -0.023438 -0.023438
# 3     -0.351562 -0.312500 -0.195312 -0.304688 -0.171875  0.890625  0.992188
# 4     -0.039062 -0.046875 -0.015625  0.656250 -0.148438 -0.023438 -0.023438
# ...         ...       ...       ...       ...       ...       ...       ...
# 59995  0.734375  0.640625  0.218750  0.992188  0.421875 -0.023438 -0.023438
# 59996 -0.289062 -0.312500 -0.195312 -0.304688 -0.171875 -0.023438 -0.023438
# 59997 -0.351562 -0.312500 -0.195312 -0.304688 -0.171875 -0.023438 -0.023438
# 59998 -0.148438 -0.132812 -0.101562  0.992188  0.992188 -0.023438 -0.023438
# 59999 -0.125000 -0.101562 -0.109375  0.070312 -0.171875 -0.023438 -0.023438
#
# [60000 rows x 171 columns]

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
#          ..
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# Length: 171, dtype: int64

# %%
dataset=dataset.replace("na",np.nan)

# %%
pd.options.display.max_rows=1000

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
# ae_000    0
# af_000    0
# ag_000    0
# ag_001    0
# ag_002    0
# ag_003    0
# ag_004    0
# ag_005    0
# ag_006    0
# ag_007    0
# ag_008    0
# ag_009    0
# ah_000    0
# ai_000    0
# aj_000    0
# ak_000    0
# al_000    0
# am_0      0
# an_000    0
# ao_000    0
# ap_000    0
# aq_000    0
# ar_000    0
# as_000    0
# at_000    0
# au_000    0
# av_000    0
# ax_000    0
# ay_000    0
# ay_001    0
# ay_002    0
# ay_003    0
# ay_004    0
# ay_005    0
# ay_006    0
# ay_007    0
# ay_008    0
# ay_009    0
# az_000    0
# az_001    0
# az_002    0
# az_003    0
# az_004    0
# az_005    0
# az_006    0
# az_007    0
# az_008    0
# az_009    0
# ba_000    0
# ba_001    0
# ba_002    0
# ba_003    0
# ba_004    0
# ba_005    0
# ba_006    0
# ba_007    0
# ba_008    0
# ba_009    0
# bb_000    0
# bc_000    0
# bd_000    0
# be_000    0
# bf_000    0
# bg_000    0
# bh_000    0
# bi_000    0
# bj_000    0
# bk_000    0
# bl_000    0
# bm_000    0
# bn_000    0
# bo_000    0
# bp_000    0
# bq_000    0
# br_000    0
# bs_000    0
# bt_000    0
# bu_000    0
# bv_000    0
# bx_000    0
# by_000    0
# bz_000    0
# ca_000    0
# cb_000    0
# cc_000    0
# cd_000    0
# ce_000    0
# cf_000    0
# cg_000    0
# ch_000    0
# ci_000    0
# cj_000    0
# ck_000    0
# cl_000    0
# cm_000    0
# cn_000    0
# cn_001    0
# cn_002    0
# cn_003    0
# cn_004    0
# cn_005    0
# cn_006    0
# cn_007    0
# cn_008    0
# cn_009    0
# co_000    0
# cp_000    0
# cq_000    0
# cr_000    0
# cs_000    0
# cs_001    0
# cs_002    0
# cs_003    0
# cs_004    0
# cs_005    0
# cs_006    0
# cs_007    0
# cs_008    0
# cs_009    0
# ct_000    0
# cu_000    0
# cv_000    0
# cx_000    0
# cy_000    0
# cz_000    0
# da_000    0
# db_000    0
# dc_000    0
# dd_000    0
# de_000    0
# df_000    0
# dg_000    0
# dh_000    0
# di_000    0
# dj_000    0
# dk_000    0
# dl_000    0
# dm_000    0
# dn_000    0
# do_000    0
# dp_000    0
# dq_000    0
# dr_000    0
# ds_000    0
# dt_000    0
# du_000    0
# dv_000    0
# dx_000    0
# dy_000    0
# dz_000    0
# ea_000    0
# eb_000    0
# ec_00     0
# ed_000    0
# ee_000    0
# ee_001    0
# ee_002    0
# ee_003    0
# ee_004    0
# ee_005    0
# ee_006    0
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# dtype: int64

# %%
[feature for feature in dataset.columns if feature not in ['class']]
# Out:
# ['aa_000',
#  'ab_000',
#  'ac_000',
#  'ad_000',
#  'ae_000',
#  'af_000',
#  'ag_000',
#  'ag_001',
#  'ag_002',
#  'ag_003',
#  'ag_004',
#  'ag_005',
#  'ag_006',
#  'ag_007',
#  'ag_008',
#  'ag_009',
#  'ah_000',
#  'ai_000',
#  'aj_000',
#  'ak_000',
#  'al_000',
#  'am_0',
#  'an_000',
#  'ao_000',
#  'ap_000',
#  'aq_000',
#  'ar_000',
#  'as_000',
#  'at_000',
#  'au_000',
#  'av_000',
#  'ax_000',
#  'ay_000',
#  'ay_001',
#  'ay_002',
#  'ay_003',
#  'ay_004',
#  'ay_005',
#  'ay_006',
#  'ay_007',
#  'ay_008',
#  'ay_009',
#  'az_000',
#  'az_001',
#  'az_002',
#  'az_003',
#  'az_004',
#  'az_005',
#  'az_006',
#  'az_007',
#  'az_008',
#  'az_009',
#  'ba_000',
#  'ba_001',
#  'ba_002',
#  'ba_003',
#  'ba_004',
#  'ba_005',
#  'ba_006',
#  'ba_007',
#  'ba_008',
#  'ba_009',
#  'bb_000',
#  'bc_000',
#  'bd_000',
#  'be_000',
#  'bf_000',
#  'bg_000',
#  'bh_000',
#  'bi_000',
#  'bj_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'bs_000',
#  'bt_000',
#  'bu_000',
#  'bv_000',
#  'bx_000',
#  'by_000',
#  'bz_000',
#  'ca_000',
#  'cb_000',
#  'cc_000',
#  'cd_000',
#  'ce_000',
#  'cf_000',
#  'cg_000',
#  'ch_000',
#  'ci_000',
#  'cj_000',
#  'ck_000',
#  'cl_000',
#  'cm_000',
#  'cn_000',
#  'cn_001',
#  'cn_002',
#  'cn_003',
#  'cn_004',
#  'cn_005',
#  'cn_006',
#  'cn_007',
#  'cn_008',
#  'cn_009',
#  'co_000',
#  'cp_000',
#  'cq_000',
#  'cr_000',
#  'cs_000',
#  'cs_001',
#  'cs_002',
#  'cs_003',
#  'cs_004',
#  'cs_005',
#  'cs_006',
#  'cs_007',
#  'cs_008',
#  'cs_009',
#  'ct_000',
#  'cu_000',
#  'cv_000',
#  'cx_000',
#  'cy_000',
#  'cz_000',
#  'da_000',
#  'db_000',
#  'dc_000',
#  'dd_000',
#  'de_000',
#  'df_000',
#  'dg_000',
#  'dh_000',
#  'di_000',
#  'dj_000',
#  'dk_000',
#  'dl_000',
#  'dm_000',
#  'dn_000',
#  'do_000',
#  'dp_000',
#  'dq_000',
#  'dr_000',
#  'ds_000',
#  'dt_000',
#  'du_000',
#  'dv_000',
#  'dx_000',
#  'dy_000',
#  'dz_000',
#  'ea_000',
#  'eb_000',
#  'ec_00',
#  'ed_000',
#  'ee_000',
#  'ee_001',
#  'ee_002',
#  'ee_003',
#  'ee_004',
#  'ee_005',
#  'ee_006',
#  'ee_007',
#  'ee_008',
#  'ee_009',
#  'ef_000',
#  'eg_000']

# %%
### Filling null values in feature with median of that feature
for feature in [feature for feature in dataset.columns if feature not in ['class']]:
    dataset[feature]=dataset[feature].fillna(dataset[feature].median())

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
# ae_000    0
# af_000    0
# ag_000    0
# ag_001    0
# ag_002    0
# ag_003    0
# ag_004    0
# ag_005    0
# ag_006    0
# ag_007    0
# ag_008    0
# ag_009    0
# ah_000    0
# ai_000    0
# aj_000    0
# ak_000    0
# al_000    0
# am_0      0
# an_000    0
# ao_000    0
# ap_000    0
# aq_000    0
# ar_000    0
# as_000    0
# at_000    0
# au_000    0
# av_000    0
# ax_000    0
# ay_000    0
# ay_001    0
# ay_002    0
# ay_003    0
# ay_004    0
# ay_005    0
# ay_006    0
# ay_007    0
# ay_008    0
# ay_009    0
# az_000    0
# az_001    0
# az_002    0
# az_003    0
# az_004    0
# az_005    0
# az_006    0
# az_007    0
# az_008    0
# az_009    0
# ba_000    0
# ba_001    0
# ba_002    0
# ba_003    0
# ba_004    0
# ba_005    0
# ba_006    0
# ba_007    0
# ba_008    0
# ba_009    0
# bb_000    0
# bc_000    0
# bd_000    0
# be_000    0
# bf_000    0
# bg_000    0
# bh_000    0
# bi_000    0
# bj_000    0
# bk_000    0
# bl_000    0
# bm_000    0
# bn_000    0
# bo_000    0
# bp_000    0
# bq_000    0
# br_000    0
# bs_000    0
# bt_000    0
# bu_000    0
# bv_000    0
# bx_000    0
# by_000    0
# bz_000    0
# ca_000    0
# cb_000    0
# cc_000    0
# cd_000    0
# ce_000    0
# cf_000    0
# cg_000    0
# ch_000    0
# ci_000    0
# cj_000    0
# ck_000    0
# cl_000    0
# cm_000    0
# cn_000    0
# cn_001    0
# cn_002    0
# cn_003    0
# cn_004    0
# cn_005    0
# cn_006    0
# cn_007    0
# cn_008    0
# cn_009    0
# co_000    0
# cp_000    0
# cq_000    0
# cr_000    0
# cs_000    0
# cs_001    0
# cs_002    0
# cs_003    0
# cs_004    0
# cs_005    0
# cs_006    0
# cs_007    0
# cs_008    0
# cs_009    0
# ct_000    0
# cu_000    0
# cv_000    0
# cx_000    0
# cy_000    0
# cz_000    0
# da_000    0
# db_000    0
# dc_000    0
# dd_000    0
# de_000    0
# df_000    0
# dg_000    0
# dh_000    0
# di_000    0
# dj_000    0
# dk_000    0
# dl_000    0
# dm_000    0
# dn_000    0
# do_000    0
# dp_000    0
# dq_000    0
# dr_000    0
# ds_000    0
# dt_000    0
# du_000    0
# dv_000    0
# dx_000    0
# dy_000    0
# dz_000    0
# ea_000    0
# eb_000    0
# ec_00     0
# ed_000    0
# ee_000    0
# ee_001    0
# ee_002    0
# ee_003    0
# ee_004    0
# ee_005    0
# ee_006    0
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# dtype: int64

# %%
pd.DataFrame(dataset.isnull().sum().sort_values(ascending=False)).rename(columns={0:"Null Value Count"})
# Out:
#         Null Value Count
# class                  0
# cs_003                 0
# cn_009                 0
# co_000                 0
# cp_000                 0
# cq_000                 0
# cr_000                 0
# cs_000                 0
# cs_001                 0
# cs_002                 0
# cs_004                 0
# cy_000                 0
# cs_005                 0
# cs_006                 0
# cs_007                 0
# cs_008                 0
# cs_009                 0
# ct_000                 0
# cu_000                 0
# cv_000                 0
# cn_008                 0
# cn_007                 0
# cn_006                 0
# cn_005                 0
# cb_000                 0
# cc_000                 0
# cd_000                 0
# ce_000                 0
# cf_000                 0
# cg_000                 0
# ch_000                 0
# ci_000                 0
# cj_000                 0
# ck_000                 0
# cl_000                 0
# cm_000                 0
# cn_000                 0
# cn_001                 0
# cn_002                 0
# cn_003                 0
# cn_004                 0
# cx_000                 0
# cz_000                 0
# bz_000                 0
# ee_001                 0
# dx_000                 0
# dy_000                 0
# dz_000                 0
# ea_000                 0
# eb_000                 0
# ec_00                  0
# ed_000                 0
# ee_000                 0
# ee_002                 0
# da_000                 0
# ee_003                 0
# ee_004                 0
# ee_005                 0
# ee_006                 0
# ee_007                 0
# ee_008                 0
# ee_009                 0
# ef_000                 0
# dv_000                 0
# du_000                 0
# dt_000                 0
# ds_000                 0
# db_000                 0
# dc_000                 0
# dd_000                 0
# de_000                 0
# df_000                 0
# dg_000                 0
# dh_000                 0
# di_000                 0
# dj_000                 0
# dk_000                 0
# dl_000                 0
# dm_000                 0
# dn_000                 0
# do_000                 0
# dp_000                 0
# dq_000                 0
# dr_000                 0
# ca_000                 0
# by_000                 0
# aa_000                 0
# av_000                 0
# an_000                 0
# ao_000                 0
# ap_000                 0
# aq_000                 0
# ar_000                 0
# as_000                 0
# at_000                 0
# au_000                 0
# ax_000                 0
# ay_009                 0
# ay_000                 0
# ay_001                 0
# ay_002                 0
# ay_003                 0
# ay_004                 0
# ay_005                 0
# ay_006                 0
# ay_007                 0
# am_0                   0
# al_000                 0
# ak_000                 0
# aj_000                 0
# ab_000                 0
# ac_000                 0
# ad_000                 0
# ae_000                 0
# af_000                 0
# ag_000                 0
# ag_001                 0
# ag_002                 0
# ag_003                 0
# ag_004                 0
# ag_005                 0
# ag_006                 0
# ag_007                 0
# ag_008                 0
# ag_009                 0
# ah_000                 0
# ai_000                 0
# ay_008                 0
# az_000                 0
# bx_000                 0
# bm_000                 0
# be_000                 0
# bf_000                 0
# bg_000                 0
# bh_000                 0
# bi_000                 0
# bj_000                 0
# bk_000                 0
# bl_000                 0
# bn_000                 0
# az_001                 0
# bo_000                 0
# bp_000                 0
# bq_000                 0
# br_000                 0
# bs_000                 0
# bt_000                 0
# bu_000                 0
# bv_000                 0
# bd_000                 0
# bc_000                 0
# bb_000                 0
# ba_009                 0
# az_002                 0
# az_003                 0
# az_004                 0
# az_005                 0
# az_006                 0
# az_007                 0
# az_008                 0
# az_009                 0
# ba_000                 0
# ba_001                 0
# ba_002                 0
# ba_003                 0
# ba_004                 0
# ba_005                 0
# ba_006                 0
# ba_007                 0
# ba_008                 0
# eg_000                 0

# %%
dataset.head()
# Out:
#       class    aa_000    ab_000    ac_000    ad_000    ae_000    af_000  \
# 0 -0.992188  0.117188 -0.289062  0.992188 -0.007812 -0.046875 -0.054688
# 1 -0.992188 -0.179688 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
# 2 -0.992188 -0.125000 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
# 3 -0.992188 -0.406250 -0.289062 -0.468750 -0.007812 -0.046875 -0.007812
# 4 -0.992188  0.007812 -0.289062 -0.468750 -0.007812 -0.046875 -0.054688
#
#      ag_000   ag_001    ag_002  ...    ee_002    ee_003    ee_004    ee_005  \
# 0 -0.007812 -0.03125 -0.054688  ...  0.687500  0.515625  0.234375  0.070312
# 1 -0.007812 -0.03125 -0.054688  ... -0.023438 -0.062500 -0.132812 -0.132812
# 2 -0.007812 -0.03125 -0.054688  ... -0.140625 -0.093750 -0.015625  0.015625
# 3 -0.007812 -0.03125 -0.054688  ... -0.382812 -0.382812 -0.375000 -0.351562
# 4 -0.007812 -0.03125 -0.054688  ...  0.156250  0.031250 -0.031250 -0.039062
#
#      ee_006    ee_007    ee_008    ee_009    ef_000    eg_000
# 0  0.007812 -0.109375 -0.140625 -0.171875 -0.023438 -0.023438
# 1 -0.187500 -0.148438 -0.085938 -0.140625 -0.023438 -0.023438
# 2 -0.007812 -0.109375 -0.093750 -0.164062 -0.023438 -0.023438
# 3 -0.312500 -0.195312 -0.304688 -0.171875  0.890625  0.992188
# 4 -0.046875 -0.015625  0.656250 -0.148438 -0.023438 -0.023438
#
# [5 rows x 171 columns]

# %%
X=dataset.drop("class",axis=1)
y=dataset["class"]

# %%
X.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 170 columns):
#  #    Column  Non-Null Count  Dtype
# ---   ------  --------------  -----
#  0    aa_000  60000 non-null  float64
#  1    ab_000  60000 non-null  float64
#  2    ac_000  60000 non-null  float64
#  3    ad_000  60000 non-null  float64
#  4    ae_000  60000 non-null  float64
#  5    af_000  60000 non-null  float64
#  6    ag_000  60000 non-null  float64
#  7    ag_001  60000 non-null  float64
#  8    ag_002  60000 non-null  float64
#  9    ag_003  60000 non-null  float64
#  10   ag_004  60000 non-null  float64
#  11   ag_005  60000 non-null  float64
#  12   ag_006  60000 non-null  float64
#  13   ag_007  60000 non-null  float64
#  14   ag_008  60000 non-null  float64
#  15   ag_009  60000 non-null  float64
#  16   ah_000  60000 non-null  float64
#  17   ai_000  60000 non-null  float64
#  18   aj_000  60000 non-null  float64
#  19   ak_000  60000 non-null  float64
#  20   al_000  60000 non-null  float64
#  21   am_0    60000 non-null  float64
#  22   an_000  60000 non-null  float64
#  23   ao_000  60000 non-null  float64
#  24   ap_000  60000 non-null  float64
#  25   aq_000  60000 non-null  float64
#  26   ar_000  60000 non-null  float64
#  27   as_000  60000 non-null  float64
#  28   at_000  60000 non-null  float64
#  29   au_000  60000 non-null  float64
#  30   av_000  60000 non-null  float64
#  31   ax_000  60000 non-null  float64
#  32   ay_000  60000 non-null  float64
#  33   ay_001  60000 non-null  float64
#  34   ay_002  60000 non-null  float64
#  35   ay_003  60000 non-null  float64
#  36   ay_004  60000 non-null  float64
#  37   ay_005  60000 non-null  float64
#  38   ay_006  60000 non-null  float64
#  39   ay_007  60000 non-null  float64
#  40   ay_008  60000 non-null  float64
#  41   ay_009  60000 non-null  float64
#  42   az_000  60000 non-null  float64
#  43   az_001  60000 non-null  float64
#  44   az_002  60000 non-null  float64
#  45   az_003  60000 non-null  float64
#  46   az_004  60000 non-null  float64
#  47   az_005  60000 non-null  float64
#  48   az_006  60000 non-null  float64
#  49   az_007  60000 non-null  float64
#  50   az_008  60000 non-null  float64
#  51   az_009  60000 non-null  float64
#  52   ba_000  60000 non-null  float64
#  53   ba_001  60000 non-null  float64
#  54   ba_002  60000 non-null  float64
#  55   ba_003  60000 non-null  float64
#  56   ba_004  60000 non-null  float64
#  57   ba_005  60000 non-null  float64
#  58   ba_006  60000 non-null  float64
#  59   ba_007  60000 non-null  float64
#  60   ba_008  60000 non-null  float64
#  61   ba_009  60000 non-null  float64
#  62   bb_000  60000 non-null  float64
#  63   bc_000  60000 non-null  float64
#  64   bd_000  60000 non-null  float64
#  65   be_000  60000 non-null  float64
#  66   bf_000  60000 non-null  float64
#  67   bg_000  60000 non-null  float64
#  68   bh_000  60000 non-null  float64
#  69   bi_000  60000 non-null  float64
#  70   bj_000  60000 non-null  float64
#  71   bk_000  60000 non-null  float64
#  72   bl_000  60000 non-null  float64
#  73   bm_000  60000 non-null  float64
#  74   bn_000  60000 non-null  float64
#  75   bo_000  60000 non-null  float64
#  76   bp_000  60000 non-null  float64
#  77   bq_000  60000 non-null  float64
#  78   br_000  60000 non-null  float64
#  79   bs_000  60000 non-null  float64
#  80   bt_000  60000 non-null  float64
#  81   bu_000  60000 non-null  float64
#  82   bv_000  60000 non-null  float64
#  83   bx_000  60000 non-null  float64
#  84   by_000  60000 non-null  float64
#  85   bz_000  60000 non-null  float64
#  86   ca_000  60000 non-null  float64
#  87   cb_000  60000 non-null  float64
#  88   cc_000  60000 non-null  float64
#  89   cd_000  60000 non-null  float64
#  90   ce_000  60000 non-null  float64
#  91   cf_000  60000 non-null  float64
#  92   cg_000  60000 non-null  float64
#  93   ch_000  60000 non-null  float64
#  94   ci_000  60000 non-null  float64
#  95   cj_000  60000 non-null  float64
#  96   ck_000  60000 non-null  float64
#  97   cl_000  60000 non-null  float64
#  98   cm_000  60000 non-null  float64
#  99   cn_000  60000 non-null  float64
#  100  cn_001  60000 non-null  float64
#  101  cn_002  60000 non-null  float64
#  102  cn_003  60000 non-null  float64
#  103  cn_004  60000 non-null  float64
#  104  cn_005  60000 non-null  float64
#  105  cn_006  60000 non-null  float64
#  106  cn_007  60000 non-null  float64
#  107  cn_008  60000 non-null  float64
#  108  cn_009  60000 non-null  float64
#  109  co_000  60000 non-null  float64
#  110  cp_000  60000 non-null  float64
#  111  cq_000  60000 non-null  float64
#  112  cr_000  60000 non-null  float64
#  113  cs_000  60000 non-null  float64
#  114  cs_001  60000 non-null  float64
#  115  cs_002  60000 non-null  float64
#  116  cs_003  60000 non-null  float64
#  117  cs_004  60000 non-null  float64
#  118  cs_005  60000 non-null  float64
#  119  cs_006  60000 non-null  float64
#  120  cs_007  60000 non-null  float64
#  121  cs_008  60000 non-null  float64
#  122  cs_009  60000 non-null  float64
#  123  ct_000  60000 non-null  float64
#  124  cu_000  60000 non-null  float64
#  125  cv_000  60000 non-null  float64
#  126  cx_000  60000 non-null  float64
#  127  cy_000  60000 non-null  float64
#  128  cz_000  60000 non-null  float64
#  129  da_000  60000 non-null  float64
#  130  db_000  60000 non-null  float64
#  131  dc_000  60000 non-null  float64
#  132  dd_000  60000 non-null  float64
#  133  de_000  60000 non-null  float64
#  134  df_000  60000 non-null  float64
#  135  dg_000  60000 non-null  float64
#  136  dh_000  60000 non-null  float64
#  137  di_000  60000 non-null  float64
#  138  dj_000  60000 non-null  float64
#  139  dk_000  60000 non-null  float64
#  140  dl_000  60000 non-null  float64
#  141  dm_000  60000 non-null  float64
#  142  dn_000  60000 non-null  float64
#  143  do_000  60000 non-null  float64
#  144  dp_000  60000 non-null  float64
#  145  dq_000  60000 non-null  float64
#  146  dr_000  60000 non-null  float64
#  147  ds_000  60000 non-null  float64
#  148  dt_000  60000 non-null  float64
#  149  du_000  60000 non-null  float64
#  150  dv_000  60000 non-null  float64
#  151  dx_000  60000 non-null  float64
#  152  dy_000  60000 non-null  float64
#  153  dz_000  60000 non-null  float64
#  154  ea_000  60000 non-null  float64
#  155  eb_000  60000 non-null  float64
#  156  ec_00   60000 non-null  float64
#  157  ed_000  60000 non-null  float64
#  158  ee_000  60000 non-null  float64
#  159  ee_001  60000 non-null  float64
#  160  ee_002  60000 non-null  float64
#  161  ee_003  60000 non-null  float64
#  162  ee_004  60000 non-null  float64
#  163  ee_005  60000 non-null  float64
#  164  ee_006  60000 non-null  float64
#  165  ee_007  60000 non-null  float64
#  166  ee_008  60000 non-null  float64
#  167  ee_009  60000 non-null  float64
#  168  ef_000  60000 non-null  float64
#  169  eg_000  60000 non-null  float64
# dtypes: float64(170)
# memory usage: 77.8 MB

# %%
y=pd.get_dummies(y,drop_first=True)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (48000, 170)
# (12000, 170)
# (48000, 1)
# (12000, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units=10,kernel_initializer='he_uniform',activation='relu',input_dim =170))

# %%
classifier.add(Dense(units = 10, kernel_initializer ='he_uniform',activation='relu'))

# %%
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform',activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss ='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                1710
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,831
# Trainable params: 1,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train
# Out:
# array([[ 0.35773533, -0.60992455, -0.47845176, ...,  0.31822293,
#         -0.06659485, -0.08265354],
#        [-0.70273574, -0.60992455, -0.47845176, ..., -0.28067807,
#         -0.06659485, -0.08265354],
#        [-0.21491904,  0.22330197, -0.47845176, ..., -0.40045827,
#         -0.06659485, -0.08265354],
#        ...,
#        [ 3.03012243, -0.60992455, -0.47845176, ..., -0.40045827,
#         -0.06659485, -0.08265354],
#        [-0.72394516, -0.60992455,  2.10764158, ..., -0.40045827,
#         -0.06659485, -0.08265354],
#        [-0.74515458,  0.22330197, -0.47845176, ..., -0.40045827,
#         -0.06659485, -0.08265354]])

# %%
model_history=classifier.fit(X_train,y_train,batch_size=10,epochs=30,validation_split=0.25)
# Out:
# Epoch 1/30
# 3600/3600 [==============================] - 10s 3ms/step - loss: 0.0481 - accuracy: 0.9845 - val_loss: 0.0269 - val_accuracy: 0.9897
# Epoch 2/30
# 3600/3600 [==============================] - 10s 3ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0241 - val_accuracy: 0.9905
# Epoch 3/30
# 3600/3600 [==============================] - 9s 2ms/step - loss: 0.0270 - accuracy: 0.9906 - val_loss: 0.0230 - val_accuracy: 0.9916
# Epoch 4/30
# 3600/3600 [==============================] - 9s 3ms/step - loss: 0.0249 - accuracy: 0.9914 - val_loss: 0.0233 - val_accuracy: 0.9917
# Epoch 5/30
# 3600/3600 [==============================] - 9s 2ms/step - loss: 0.0239 - accuracy: 0.9914 - val_loss: 0.0256 - val_accuracy: 0.9902
# Epoch 6/30
# 3600/3600 [==============================] - 10s 3ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.0237 - val_accuracy: 0.9913
# Epoch 7/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.0227 - val_accuracy: 0.9912
# Epoch 8/30
# 3600/3600 [==============================] - 13s 4ms/step - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.0250 - val_accuracy: 0.9910
# Epoch 9/30
# 3600/3600 [==============================] - 13s 4ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0270 - val_accuracy: 0.9913
# Epoch 10/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0196 - accuracy: 0.9927 - val_loss: 0.0240 - val_accuracy: 0.9916
# Epoch 11/30
# 3600/3600 [==============================] - 9s 3ms/step - loss: 0.0195 - accuracy: 0.9928 - val_loss: 0.0241 - val_accuracy: 0.9918
# Epoch 12/30
# 3600/3600 [==============================] - 10s 3ms/step - loss: 0.0185 - accuracy: 0.9930 - val_loss: 0.0249 - val_accuracy: 0.9915
# Epoch 13/30
# 3600/3600 [==============================] - 13s 4ms/step - loss: 0.0176 - accuracy: 0.9935 - val_loss: 0.0254 - val_accuracy: 0.9916
# Epoch 14/30
# 3600/3600 [==============================] - 12s 3ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.0252 - val_accuracy: 0.9922
# Epoch 15/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0261 - val_accuracy: 0.9914
# Epoch 16/30
# 3600/3600 [==============================] - 12s 3ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0281 - val_accuracy: 0.9915
# Epoch 17/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.0315 - val_accuracy: 0.9915
# Epoch 18/30
# 3600/3600 [==============================] - 10s 3ms/step - loss: 0.0159 - accuracy: 0.9939 - val_loss: 0.0282 - val_accuracy: 0.9921
# Epoch 19/30
# 3600/3600 [==============================] - 12s 3ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 0.0317 - val_accuracy: 0.9904
# Epoch 20/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 0.0307 - val_accuracy: 0.9902
# Epoch 21/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0286 - val_accuracy: 0.9917
# Epoch 22/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0346 - val_accuracy: 0.9911
# Epoch 23/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0315 - val_accuracy: 0.9921
# Epoch 24/30
# 3600/3600 [==============================] - 9s 2ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.0373 - val_accuracy: 0.9893
# Epoch 25/30
# 3600/3600 [==============================] - 12s 3ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 0.0391 - val_accuracy: 0.9912
# Epoch 26/30
# 3600/3600 [==============================] - 9s 3ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.0344 - val_accuracy: 0.9915
# Epoch 27/30
# 3600/3600 [==============================] - 11s 3ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.0408 - val_accuracy: 0.9898
# Epoch 28/30
# 3600/3600 [==============================] - 12s 3ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0374 - val_accuracy: 0.9906
# Epoch 29/30
# 3600/3600 [==============================] - 7s 2ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.0338 - val_accuracy: 0.9917
# Epoch 30/30
# 3600/3600 [==============================] - 9s 3ms/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 0.0393 - val_accuracy: 0.9912

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_history.history['accuracy']
# Out:
# [0.9844722151756287,
#  0.9894722104072571,
#  0.9905833601951599,
#  0.9913610816001892,
#  0.9913889169692993,
#  0.9921388626098633,
#  0.992388904094696,
#  0.9926111102104187,
#  0.9925000071525574,
#  0.9926666617393494,
#  0.992805540561676,
#  0.992972195148468,
#  0.9935277700424194,
#  0.9935555458068848,
#  0.9939722418785095,
#  0.9942499995231628,
#  0.9943333268165588,
#  0.9939444661140442,
#  0.9942499995231628,
#  0.9942777752876282,
#  0.9945555329322815,
#  0.9949444532394409,
#  0.9948889017105103,
#  0.9951944351196289,
#  0.9948889017105103,
#  0.9950555562973022,
#  0.9951944351196289,
#  0.9953610897064209,
#  0.9953888654708862,
#  0.995555579662323]

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred=classifier.predict(X_test)
# Out:
# 563/563 [==============================] - 1s 1ms/step

# %%
X_test.shape
# Out:
# (18000, 170)

# %%
#for the sigmoid my threshold is 0.
y_pred=y_pred>0.5
from sklearn.metrics import confusion_matrix

# %%
y_test.shape
# Out:
# (18000,)

# %%
y_pred.shape
# Out:
# (18000, 1)

# %% [markdown]
# ## #hyperparameter tunig with keras tuner

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.2.1-py3-none-any.whl (169 kB)
# Requirement already satisfied: tensorflow>=2.0 in c:\anaconda\lib\site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: ipython in c:\anaconda\lib\site-packages (from keras-tuner) (8.2.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from keras-tuner) (2.28.1)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\anaconda\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.6.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.19.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (61.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.42.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.30.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\anaconda\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->keras-tuner) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.2.2)
# Requirement already satisfied: traitlets>=5 in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: decorator in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.1.2)
# Requirement already satisfied: stack-data in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.4.4)
# Requirement already satisfied: backcall in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pickleshare in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\anaconda\lib\site-packages (from ipython->keras-tuner) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconda\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in c:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda\lib\site-packages (from packaging->keras-tuner) (3.0.4)
# Requirement already satisfied: asttokens in c:\anaconda\lib\site-packages (from stack-data->ipython->keras-tuner) (2.0.5)
# Requirement already satisfied: executing in c:\anaconda\lib\site-packages (from stack-data->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: pure-eval in c:\anaconda\lib\site-packages (from stack-data->ipython->keras-tuner) (0.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.2.1 kt-legacy-1.0.4

# %%
from kerastuner.tuners import RandomSearch
# Out:
# C:\Users\SANJIVANI\AppData\Local\Temp\ipykernel_88\2610907151.py:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
    model=Sequential()
    model.add(Dense(units=32,kernel_initializer ='he_uniform',activation='relu',input_dim=170))
    model.add(Dense(units = 32, kernel_initializer ='he_uniform',activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    optimizer=hp.Choice("optimizer",values=["adam","sgd","rmsprop","adadelta"])
    model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
    return model

# %%
tuner=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='project1',project_name='aps-fault')

# %%
tuner.search(X_train,y_train,validation_data=(X_test,y_test),epochs=5)
# Out:
# Trial 4 Complete [00h 00m 15s]
# val_accuracy: 0.0
#
# Best val_accuracy So Far: 0.0
# Total elapsed time: 00h 01m 08s
# INFO:tensorflow:Oracle triggered exit

# %%
mymodel=tuner.get_best_models(num_models=1)[0]

# %%
mymodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                5472
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6,561
# Trainable params: 6,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
def build_model(hp):
    model = Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
            model.add(Dense(units=hp.Int('units_' + str(i),min_value=32,max_value=512,step=32),activation='relu'))
            model.add(Dense(1, activation='sigmoid'))
            model.compile(optimizer=optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),loss='binary_crossentropy',metrics=['accuracy'])
            return model

# %%
tuner_second=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='project3',project_name='aps-fault-sensor')

# %%
tuner_second.search(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Trial 5 Complete [00h 00m 18s]
# val_accuracy: 0.0
#
# Best val_accuracy So Far: 0.0
# Total elapsed time: 00h 01m 34s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner_second.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 6, 'units_0': 288, 'learning_rate': 0.001}

# %%
classifier2=tuner_second.get_best_models(num_models=1)[0]

# %%
classifier2
